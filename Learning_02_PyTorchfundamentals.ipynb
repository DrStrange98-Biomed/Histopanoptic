# %% [markdown]
# <a href="https://colab.research.google.com/github/DrStrange98-Biomed/Histopanoptic/blob/main/Learning_02_PyTorchfundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %% [markdown]
# PyTorch an open source machine learning and deep learning framework. Write machine learning algorithms using python code.
#
# Real Time Examples where PyTorch is used - Self-driving computer vision models, in agriculture - power computer vision on tractors, Power research.
#
# 1. Tensors are the basic building block of all machine learning and deep learning frameworks.
# 2. Tensors are nothing but the data which can be images, words, table of numbers.
# 3. Most common issues in machine learning is dealing with shape mismatches (trying to mix wrong shaped tensors with other sensors)
# 4. Pytorch plays with tensors, whereas NumPy deals with arrays.
# 5. Pytorch makes it esay to run the code on GPUs for faster access.
