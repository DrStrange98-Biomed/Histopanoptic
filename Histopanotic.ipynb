# %% [markdown]
# <a href="https://colab.research.google.com/github/DrStrange98-Biomed/Histopanoptic/blob/main/Histopanotic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import sys
import platform

print(f"Python: {platform.python_version()}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available()}")
print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory/1e9:.2f}GB" if torch.cuda.is_available()else "")
# Out:
#   File "/tmp/ipykernel_1444/2635083118.py", line 8
#     print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available()}")
#                   ^
# SyntaxError: expected 'else' after 'if' expression

# %%
import torch
import sys
import platform

print(f"Python: {platform.python_version()}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB" if torch.cuda.is_available() else "")
# Out:
# Python: 3.12.13
# PyTorch: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4
# GPU memory: 15.64 GB

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
project_dir = '/content/drive/MyDrive/histopanoptic'
os.makedirs(project_dir, exist_ok=True)
print(f"Project directory ready: {project_dir}")
print(f"Contents: {os.listdir(project_dir)}")
# Out:
# Project directory ready: /content/drive/MyDrive/histopanoptic
# Contents: []

# %% [markdown]
# # HistoPanoptic — Setup & Environment Check
#
# **Objective:** Verify Colab environment, GPU access, and Google Drive integration.
#
# **Date:** 21/05/2026
# **Author:** Mahesh Ravichandran
#
# ## Steps performed
# 1. Connected to Colab T4 GPU runtime
# 2. Verified PyTorch CUDA availability
# 3. Mounted Google Drive for persistent storage
# 4. Created project directory at `/content/drive/MyDrive/histopanoptic`
