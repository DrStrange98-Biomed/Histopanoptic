# %% [markdown]
# <a href="https://colab.research.google.com/github/DrStrange98-Biomed/Histopanoptic/blob/main/Neural_Networks_and_ML_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Youtube Video 1:
# 3Blue1Brown
#
# Short Notes:
#
# Chapter 1
#
# Convolutional Neural Network - Good for Image recognition
#
# Long Short-term memory Network - Good for Speech recognition
#
# Plain Vanilla aka multilayer perceptron
#
# Neuron - thing that holds the number between 0 and 1 (0.1-0.9)
# 28 x 28 pixel image holds 784 neurons.
#
# Grayscale image values 0 for black pixel and 1 for white pixel
# Value inside the neuron known as activation
#
# Input Layer ---> Hidden Layers ----> Output Layer
#
# Activations with weights being computed for desired output
# Sigma(w1a1+ w2a2+.........wNaN-10) Bias - 10 (Weights and Bias)
# For 784 neurons with two layers, first layer consists of 16 weights and 16 bias and in second layer 16 weights and 16 bias whereas for the output layer no weights only 10 bias. In total 16x16x10 bias
#
# 784x16+16x16+16x10 = 13002 weights and biases which can be tweaked and turned.
#
# Learning - Finding the right weights and biases by the computer
#
# For Proper Organization - make activations as vector and all weights as matrix + bias as vector. Sigmoid of all these paves the way for learning.
#
# Sigmoid or logistic curve which is old. ReLU - Rectified Linear Matrix is much faster to train. ReLU(a) = max(0,a)
#
# Network -> Function
#
# *Chapter 2:*
#
# Machine Learning - Its just calculus in simple terms finding minima of certain functions _ Other words Start at any function and figure out at which direction you step to make the output lower
#
# Input = 784 neurons
# Output = 10 numbers
# Parameters = 13002
#
# Using Cost function
# Input = 13002 weights and biases
# Output = 1 number (the cost = difference)
# Parameters = Many many training examples or trained datasets
#
# Gradient - Direction of Steepest Increase. Direction to increase the function quickly.
#
# Gradient Descent - Convergernt to find the local minima
#
# Analyzing the network - Test the data and if not correct data should be able to recognize wrong and perform right computations
#
# Chapter 3:
#
# Backpropagation - algorithm used to train deep learning neural networks
# Compute gradient descent step using backprop
# Other techniques - Cost Surface, Stochastic Gradient descent, mini-batches
# Challenges in ML - To get labelled training data
#
# Backpropagation Calculus, Sensitivity to weights and biases.
